# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<2,>=1.18 in /home/codespace/.local/lib/python3.10/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /home/codespace/.local/lib/python3.10/site-packages (from statsmodels) (1.12.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.0 in /home/codespace/.local/lib/python3.10/site-packages (from statsmodels) (2.2.0)
# Collecting patsy>=0.5.4 (from statsmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.10/site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.0->statsmodels) (2023.4)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.10/site-packages (from patsy>=0.5.4->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 42.9 MB/s eta 0:00:0000:010:01
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 5.2 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import statsmodels.formula.api as sm

# %%
dataset_Facebook = pd.read_csv('dataset_Facebook.csv')
dataset_Facebook.head()
# Out:
#    Page_total_likes    Type  Post_Month  Post_Weekday  Post_Hour   Payment  \
# 0            139441   Photo          12             4          3  Not_Paid
# 1            139441  Status          12             3         10  Not_Paid
# 2            139441   Photo          12             3          3  Not_Paid
# 3            139441   Photo          12             2         10      Paid
# 4            139441   Photo          12             2          3  Not_Paid
#
#    Lifetime_Post_Total_Reach  Lifetime_Post_Total_Impressions  \
# 0                       2752                             5091
# 1                      10460                            19057
# 2                       2413                             4373
# 3                      50128                            87991
# 4                       7244                            13594
#
#    Lifetime_Engaged_Users  Lifetime_Post_Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime_Post_Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime_Post_Impressions_by_people_who_have_liked_your_Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime_Post_reach_by_people_who_like_your_Page  \
# 0                                              1640
# 1                                              6112
# 2                                              1503
# 3                                             32048
# 4                                              3200
#
#    Lifetime_People_who_have_liked_your_Page_and_engaged_with_your_post  \
# 0                                                119
# 1                                               1108
# 2                                                132
# 3                                               1386
# 4                                                396
#
#    comment  like  share  Total_Interactions
# 0        4    79     17                 100
# 1        5   130     29                 164
# 2        0    66     14                  80
# 3       58  1572    147                1777
# 4       19   325     49                 393

# %%
model1 = sm.ols(formula='Page_total_likes ~ Total_Interactions + Lifetime_Post_Consumers', data = dataset_Facebook).fit()
print (model1.summary())

# p_value = model1.pvalues['Total_Interactions']
# if p_value < 0.05: print('Total_Interactions is significant')
# else: print('Total_Interactions is not significant')


for v in model1.pvalues.keys():
    if model1.pvalues[v] < 0.05: print(f'{v} is significant')
    else: print(f'{v} is not significant')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Page_total_likes   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     8.490
# Date:                Thu, 07 Mar 2024   Prob (F-statistic):           0.000237
# Time:                        13:09:59   Log-Likelihood:                -5491.5
# No. Observations:                 495   AIC:                         1.099e+04
# Df Residuals:                     492   BIC:                         1.100e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                1.249e+05    987.214    126.525      0.000    1.23e+05    1.27e+05
# Total_Interactions          4.8543      2.011      2.414      0.016       0.903       8.805
# Lifetime_Post_Consumers    -3.4475      0.867     -3.976      0.000      -5.151      -1.744
# ==============================================================================
# Omnibus:                       54.122   Durbin-Watson:                   0.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.697
# Skew:                          -0.899   Prob(JB):                     1.21e-15
# Kurtosis:                       2.688   Cond. No.                     1.68e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept is significant
# Total_Interactions is significant
# Lifetime_Post_Consumers is significant

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as sm
insurance = pd.read_csv('insurance.csv')
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import pandas as pd
insurance = pd.read_csv('insurance.csv')

# %%
import numpy as np
insurance['east_west'] = np.where((insurance['region']=='southwest') | (insurance['region']=='northwest'), 1, 0)
#recode the categorical variables while we're at it
dummies = pd.get_dummies(insurance[['sex','smoker']])
insurance = pd.concat([insurance,dummies],axis=1)
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  east_west  \
# 0   19  female  27.900         0    yes  southwest  16884.92400          1
# 1   18    male  33.770         1     no  southeast   1725.55230          0
# 2   28    male  33.000         3     no  southeast   4449.46200          0
# 3   33    male  22.705         0     no  northwest  21984.47061          1
# 4   32    male  28.880         0     no  northwest   3866.85520          1
#
#    sex_female  sex_male  smoker_no  smoker_yes
# 0        True     False      False        True
# 1       False      True       True       False
# 2       False      True       True       False
# 3       False      True       True       False
# 4       False      True       True       False

# %%
import statsmodels.formula.api as sm
model1a = sm.ols('charges~east_west', data = insurance).fit()
print(model1a.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     6.829
# Date:                Thu, 07 Mar 2024   Prob (F-statistic):            0.00907
# Time:                        13:27:38   Log-Likelihood:                -14474.
# No. Observations:                1338   AIC:                         2.895e+04
# Df Residuals:                    1336   BIC:                         2.896e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.411e+04    460.687     30.627      0.000    1.32e+04     1.5e+04
# east_west  -1727.2761    660.963     -2.613      0.009   -3023.914    -430.638
# ==============================================================================
# Omnibus:                      332.714   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              640.370
# Skew:                           1.500   Prob(JB):                    8.82e-140
# Kurtosis:                       4.577   Cond. No.                         2.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model1b = sm.ols('charges~east_west+age',data=insurance).fit()
print(model1b.summary()) #east_west stays significant
model1c = sm.ols('charges~east_west+sex_female',data=insurance).fit()
print(model1c.summary()) #east_west stays significant
model1d = sm.ols('charges~east_west+bmi',data=insurance).fit()
print(model1d.summary()) #east_west is no longer significant
model1e = sm.ols('charges~east_west+children',data=insurance).fit()
print(model1e.summary()) #east_west stays significant
model1f = sm.ols('charges~east_west+smoker_yes',data=insurance).fit()
print(model1f.summary()) #east_west is no longer significant
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     69.95
# Date:                Thu, 07 Mar 2024   Prob (F-statistic):           1.29e-29
# Time:                        13:28:22   Log-Likelihood:                -14411.
# No. Observations:                1338   AIC:                         2.883e+04
# Df Residuals:                    1335   BIC:                         2.884e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4013.5035    981.395      4.090      0.000    2088.259    5938.748
# east_west  -1787.1060    630.699     -2.834      0.005   -3024.374    -549.838
# age          258.2469     22.444     11.506      0.000     214.217     302.277
# ==============================================================================
# Omnibus:                      396.151   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              851.563
# Skew:                           1.721   Prob(JB):                    1.22e-185
# Kurtosis:                       4.852   Cond. No.                         134.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     5.561
# Date:                Thu, 07 Mar 2024   Prob (F-statistic):            0.00394
# Time:                        13:28:22   Log-Likelihood:                -14472.
# No. Observations:                1338   AIC:                         2.895e+04
# Df Residuals:                    1335   BIC:                         2.897e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           1.478e+04    561.784     26.302      0.000    1.37e+04    1.59e+04
# sex_female[T.True] -1364.6826    659.981     -2.068      0.039   -2659.395     -69.970
# east_west          -1709.3082    660.211     -2.589      0.010   -3004.473    -414.144
# ==============================================================================
# Omnibus:                      327.475   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              624.482
# Skew:                           1.482   Prob(JB):                    2.49e-136
# Kurtosis:                       4.555   Cond. No.                         3.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     28.97
# Date:                Thu, 07 Mar 2024   Prob (F-statistic):           4.84e-13
# Time:                        13:28:22   Log-Likelihood:                -14449.
# No. Observations:                1338   AIC:                         2.890e+04
# Df Residuals:                    1335   BIC:                         2.892e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2111.0072   1742.318      1.212      0.226   -1306.973    5528.987
# east_west  -1158.3862    653.851     -1.772      0.077   -2441.074     124.301
# bmi          382.2851     53.609      7.131      0.000     277.119     487.452
# ==============================================================================
# Omnibus:                      260.518   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              430.233
# Skew:                           1.292   Prob(JB):                     3.77e-94
# Kurtosis:                       4.019   Cond. No.                         169.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     6.820
# Date:                Thu, 07 Mar 2024   Prob (F-statistic):            0.00113
# Time:                        13:28:22   Log-Likelihood:                -14471.
# No. Observations:                1338   AIC:                         2.895e+04
# Df Residuals:                    1335   BIC:                         2.896e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.336e+04    541.875     24.660      0.000    1.23e+04    1.44e+04
# east_west  -1796.1832    660.068     -2.721      0.007   -3091.066    -501.300
# children     712.9527    273.767      2.604      0.009     175.892    1250.013
# ==============================================================================
# Omnibus:                      336.689   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              652.772
# Skew:                           1.513   Prob(JB):                    1.79e-142
# Kurtosis:                       4.597   Cond. No.                         4.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.620
# Model:                            OLS   Adj. R-squared:                  0.620
# Method:                 Least Squares   F-statistic:                     1090.
# Date:                Thu, 07 Mar 2024   Prob (F-statistic):          2.16e-281
# Time:                        13:28:23   Log-Likelihood:                -13830.
# No. Observations:                1338   AIC:                         2.767e+04
# Df Residuals:                    1335   BIC:                         2.768e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           8695.4846    307.618     28.267      0.000    8092.018    9298.952
# smoker_yes[T.True]  2.358e+04    506.978     46.501      0.000    2.26e+04    2.46e+04
# east_west           -520.4759    409.340     -1.271      0.204   -1323.497     282.545
# ==============================================================================
# Omnibus:                      135.418   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              211.707
# Skew:                           0.724   Prob(JB):                     1.07e-46
# Kurtosis:                       4.304   Cond. No.                         3.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
